# %% [markdown]
# # 📘 03 - Python Dictionaries
#
# Dictionaries store key-value pairs for fast lookups.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and access dictionary items
# - Use dictionary methods like `.get()` and `.items()`

# %%
# 📚 Create a Dictionary
student = {'name': 'Alex', 'age': 21, 'major': 'CS'}
print(student)

# %%
# 🔍 Access Values
print(student['name'])
print(student.get('gpa', 'N/A'))

# %%
# 🔁 Loop Over Dictionary
for key, value in student.items():
    print(key, '->', value)

# %% [markdown]
# ## ✏️ Your Turn
# Create a dictionary to store information about your favorite book.

# %%
fav_book = {'title': 'Harry Potter', 'author': 'J.K. Rowling', 'year': 1997}

print(fav_book)

print("title:", fav_book['title'])
print("author: ", fav_book['author'])
print("year: ", fav_book['year'])
# Out:
# {'title': 'Harry Potter', 'author': 'J.K. Rowling', 'year': 1997}
# title: Harry Potter
# author:  J.K. Rowling
# year:  1997

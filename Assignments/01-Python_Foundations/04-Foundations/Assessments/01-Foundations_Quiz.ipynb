# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# %whos displays all variables and objects currently stored in memory.

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# ## My Hobbies
#
# - Playing video games
# - Soccer
# - Drawing

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
# %pwd
# Out:
# 'c:\\Users\\andre\\OneDrive\\Documentos\\Uni\\Griffin\\4545-5993-Spatial-Data\\4545-5993-Spatial-Data\\Assignments\\01-Python_Foundations\\04-Foundations\\Assessments'

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
with open("hello.txt", "w") as file:
    file.write("Hello, World!")

with open("hello.txt", "r") as file:
    content = file.read()
    
print(content)
# Out:
# Hello, World!

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
# Out:
#   Cell In[7], line 1
#     -m pip install --upgrade pip
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "Luis", "Briam"],
    "Grade": [90, 85, 92, 88, 95]
}

df = pd.DataFrame(data)
df.to_csv("students.csv", index=False)
students = pd.read_csv("students.csv")
students.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2
#       3 data = {
#       4     "Name": ["Alice", "Bob", "Charlie", "Luis", "Briam"],
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt

x = list(range(11))
y = [i**2 for i in x]

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y = x^2")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2
#       3 x = list(range(11))
#       4 y = [i**2 for i in x]
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# Press D twice (DD) in Command mode.

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
numbers = list(range(1000))

# %timeit [x**2 for x in numbers]

result = []
# %timeit 
for x in numbers:
    result.append(x**2)
# Out:
# 91 μs ± 3.3 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# Mixing markdown and code in Jupyter notebooks makes it easier to explain what the code is doing. Markdown can be used for notes, headings, and instructions while code cells run the program. This helps organize projects and make notebooks easier to read.

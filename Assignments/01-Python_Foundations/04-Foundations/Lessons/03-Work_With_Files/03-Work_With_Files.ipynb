# %% [markdown]
# # 📂 03 - Working with Files and Paths
#
# Data science means working with files all the time: datasets, config files, logs.
# This notebook introduces:
# - Checking your current path in Jupyter
# - Navigating directories
# - Reading and writing text files
# - Using `with` for safe file handling
# - Basics of JSON and CSV I/O

# %% [markdown]
# ## 1. Where Am I?

# %%
# %pwd  # Print current working directory

# %%
# %ls  # List files in the current directory

# %%
# %cd ..  # Change to parent directory
# %pwd

# %% [markdown]
# ✅ **Your Turn**: Navigate into a subfolder of your repo (e.g., `Foundations/`) and list its contents.

# %%
# %cd ..
# %ls
# Out:
# c:\Users\andre\OneDrive\Documentos\Uni\Griffin\4545-5993-Spatial-Data\4545-5993-Spatial-Data\Assignments\01-Python_Foundations\04-Foundations\Lessons
#  El volumen de la unidad C es Windows
#  El n�mero de serie del volumen es: 8252-64E6
#
#  Directorio de c:\Users\andre\OneDrive\Documentos\Uni\Griffin\4545-5993-Spatial-Data\4545-5993-Spatial-Data\Assignments\01-Python_Foundations\04-Foundations\Lessons
#
# 05/05/2026  01:02 PM    <DIR>          .
# 05/05/2026  01:02 PM    <DIR>          ..
# 05/05/2026  01:02 PM    <DIR>          01-Magic_Commands
# 05/05/2026  01:02 PM    <DIR>          02-Markdown_and_Formatting
# 05/05/2026  01:02 PM    <DIR>          03-Work_With_Files
# 05/05/2026  01:02 PM    <DIR>          04-Data_Input_Output
# 05/05/2026  01:02 PM    <DIR>          05-Plotting_Basics
# 05/05/2026  01:02 PM    <DIR>          06-Jupyter_Shortcuts_and_Productivity
# 05/05/2026  01:02 PM    <DIR>          07-Using_Help_and_Docs
# 05/05/2026  01:02 PM    <DIR>          08-Timing_and_Performance
#                0 archivos              0 bytes
#               10 dirs  15,938,904,064 bytes libres

# %% [markdown]
# ## 2. Writing and Reading Text Files

# %%
# Writing to a text file
with open("example.txt", "w") as f:
    f.write("Hello, Jupyter!\n")
    f.write("This is a text file.\n")

# %%
# Reading from a text file
with open("example.txt", "r") as f:
    contents = f.read()
contents

# %% [markdown]
# ✅ **Your Turn**: Write your name into a file called `me.txt`, then read it back and print the result.

# %%
with open("me.txt", "w") as f:
    f.write("Andrea")

with open("me.txt", "r") as f:
    contents = f.read()

print(contents)
# Out:
# Andrea

# %% [markdown]
# ## 3. JSON Files

# %%
import json

data = {"name": "Graylian", "type": "mascot", "skills": ["howl", "parrot talk"]}

# Write JSON
with open("data.json", "w") as f:
    json.dump(data, f)

# Read JSON
with open("data.json", "r") as f:
    loaded = json.load(f)
loaded

# %% [markdown]
# ✅ **Your Turn**: Create a dictionary with your name and 2-3 favorite courses. Save it to `courses.json`, then read it back.

# %%
import json

courses = {
    "name": "Andrea",
    "fav_courses": ["Operating Systems", "Data Structures", "Algorithms"]
}

with open("courses.json", "w") as f:
    json.dump(courses, f)

with open("courses.json", "r") as f:
    loaded_courses = json.load(f)

print(loaded_courses)
# Out:
# {'name': 'Andrea', 'fav_courses': ['Operating Systems', 'Data Structures', 'Algorithms']}

# %% [markdown]
# ## 4. CSV Files

# %%
import csv

# Writing CSV
rows = [["Name", "Score"], ["Alice", 90], ["Bob", 85]]
with open("scores.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# Reading CSV
with open("scores.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)

# %% [markdown]
# ✅ **Your Turn**: Create a CSV with 3 rows of your own data (e.g., pets, grades, or hobbies). Read it back and display the rows.

# %%
import csv

rows = [
    ["Game", "Hours Played"],
    ["Minecraft", 120],
    ["Valorant", 85],
    ["Overwatch", 200]
]

with open("games.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

with open("games.csv", "r") as f:
    reader = csv.reader(f)
    
    for row in reader:
        print(row)
# Out:
# ['Game', 'Hours Played']
# ['Minecraft', '120']
# ['Valorant', '85']
# ['Overwatch', '200']

# %% [markdown]
# ---
# ### Summary
# - `%pwd`, `%ls`, `%cd` show you where you are in the filesystem.
# - Use `with open(...)` to safely read/write files.
# - JSON is for structured data (key/value).
# - CSV is for tabular data (rows/columns).
# - Managing files is step 1 in any real data science project.

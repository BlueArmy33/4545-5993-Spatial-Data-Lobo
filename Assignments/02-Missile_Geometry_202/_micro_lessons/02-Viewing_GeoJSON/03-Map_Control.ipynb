# %% [markdown]
# ## 03 — Map Controls
#
# So far we have added layers to a map by calling `m.add()`. Controls work the same way — they are widgets you attach to the map — but instead of drawing features, they add **UI elements**: layer toggles, a scale bar, a fullscreen button, a minimap.
#
# This lesson covers the controls you will use most often.

# %% [markdown]
# ## Layers vs Controls
#
# | `m.add(...)` argument | What it does |
# |---|---|
# | `GeoJSON(...)` | draws geographic features on the map |
# | `TileLayer(...)` | draws a background tileset |
# | `LayersControl(...)` | adds a toggle panel for named layers |
# | `ScaleControl(...)` | adds a distance scale bar |
# | `FullscreenControl(...)` | adds a fullscreen button |
# | `MiniMap(...)` | adds a small overview map in the corner |
#
# All of these go through the same `m.add()` call. The map does not distinguish — it just manages a list of things attached to it.

# %% [markdown]
# ## Setup
#
# Load the GeoJSON data from the previous lesson and split it by geometry type.

# %%
import json
from ipyleaflet import Map, GeoJSON

WICHITA_FALLS = (33.9137, -98.4934)

with open("data/wichita_falls.geojson") as f:
    all_features = json.load(f)["features"]

points   = [f for f in all_features if f["geometry"]["type"] == "Point"]
lines    = [f for f in all_features if f["geometry"]["type"] == "LineString"]
polygons = [f for f in all_features if f["geometry"]["type"] == "Polygon"]

def make_fc(features):
    return {"type": "FeatureCollection", "features": features}

# %% [markdown]
# ## LayersControl
#
# `LayersControl` adds a panel in the corner that lets users toggle layers on and off. For it to work, each layer needs a **`name`** — that name appears as the label in the toggle panel.

# %%
from ipyleaflet import Map, GeoJSON, LayersControl

m = Map(center=WICHITA_FALLS, zoom=12)

# Give each layer a name — this is what appears in the toggle panel
point_layer = GeoJSON(data=make_fc(points),   name="Points of Interest")
line_layer  = GeoJSON(data=make_fc(lines),    name="Routes")
poly_layer  = GeoJSON(data=make_fc(polygons), name="Park Boundary")

m.add(point_layer)
m.add(line_layer)
m.add(poly_layer)

# Add the control — it automatically picks up all named layers
m.add(LayersControl())

m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Click the stacked-layers icon in the top-right to expand the panel. Each named layer has a checkbox — uncheck one to hide it.
#
# Layers added **without** a `name` do not appear in the toggle panel.

# %% [markdown]
# ## ScaleControl
#
# `ScaleControl` draws a scale bar that updates as you zoom. It shows both metric and imperial units by default.

# %%
from ipyleaflet import Map, ScaleControl

m = Map(center=WICHITA_FALLS, zoom=12)
m.add(ScaleControl(position="bottomleft"))
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# The `position` argument accepts `"topleft"`, `"topright"`, `"bottomleft"`, or `"bottomright"`. All controls support this argument.

# %% [markdown]
# ## FullscreenControl
#
# `FullscreenControl` adds a button that expands the map to fill the browser window — useful when inspecting dense data.

# %%
from ipyleaflet import Map, GeoJSON, FullScreenControl

m = Map(center=WICHITA_FALLS, zoom=12)
m.add(GeoJSON(data=make_fc(all_features)))
m.add(FullScreenControl(position="topright"))
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## MiniMap
#
# `MiniMap` places a small overview map in a corner. It stays zoomed out while you navigate the main map — useful for keeping track of where you are at high zoom levels.

# %%
# !pip install --upgrade ipyleaflet
# Out:
# Requirement already satisfied: ipyleaflet in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.5.0 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (0.8.2)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (8.1.8)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (0.2.3)
# Requirement already satisfied: xyzservices>=2021.8.1 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (2026.3.0)
# Requirement already satisfied: jinja2>=3 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from branca>=0.5.0->ipyleaflet) (3.1.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (9.13.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.52)
# Requirement already satisfied: psutil>=7 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\andre\appdata\roaming\python\python312\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.7)
# Requirement already satisfied: wcwidth in c:\users\andre\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\andre\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# [notice] A new release of pip is available: 24.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ipyleaflet
[name for name in dir(ipyleaflet) if "Mini" in name or "Control" in name]
# Out:
# ['AttributionControl',
#  'ColormapControl',
#  'Control',
#  'ControlException',
#  'DrawControl',
#  'DrawControlBase',
#  'DrawControlCompatibility',
#  'FullScreenControl',
#  'GeomanDrawControl',
#  'LayersControl',
#  'LegendControl',
#  'MeasureControl',
#  'ScaleControl',
#  'SearchControl',
#  'SplitMapControl',
#  'WidgetControl',
#  'ZoomControl']

# %%
from ipyleaflet import Map, MiniMap

m = Map(center=WICHITA_FALLS, zoom=13)
m.add(MiniMap(position="bottomright"))
m
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ipyleaflet import Map, MiniMap
#       2
#       3 m = Map(center=WICHITA_FALLS, zoom=13)
#       4 m.add(MiniMap(position="bottomright"))
#
# ImportError: cannot import name 'MiniMap' from 'ipyleaflet' (c:\Users\andre\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipyleaflet\__init__.py)

# %% [markdown]
# ## Putting It Together
#
# Controls compose — you can add as many as you need to a single map.

# %%
from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl, FullscreenControl, MiniMap

m = Map(center=WICHITA_FALLS, zoom=12)

# Layers
m.add(GeoJSON(data=make_fc(points),   name="Points of Interest"))
m.add(GeoJSON(data=make_fc(lines),    name="Routes"))
m.add(GeoJSON(data=make_fc(polygons), name="Park Boundary"))

# Controls
m.add(LayersControl(position="topright"))
m.add(ScaleControl(position="bottomleft"))
m.add(FullscreenControl(position="topleft"))
m.add(MiniMap(position="bottomright"))

m
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl, FullscreenControl, MiniMap
#       2
#       3 m = Map(center=WICHITA_FALLS, zoom=12)
#       4
#
# ImportError: cannot import name 'FullscreenControl' from 'ipyleaflet' (c:\Users\andre\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipyleaflet\__init__.py)

# %% [markdown]
# ## Exercise A
#
# Rebuild the "Putting It Together" map using `basemaps.Esri.WorldImagery` (satellite tiles) instead of the default street map. Keep all three named layers and all four controls.

# %%
# !pip install ipyleaflet ipywidgets
# Out:
# Requirement already satisfied: ipyleaflet in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (0.20.0)
# Requirement already satisfied: ipywidgets in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (8.1.8)
# Requirement already satisfied: branca>=0.5.0 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (0.8.2)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (0.2.3)
# Requirement already satisfied: xyzservices>=2021.8.1 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipyleaflet) (2026.3.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipywidgets) (9.13.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipywidgets) (5.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: jinja2>=3 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from branca>=0.5.0->ipyleaflet) (3.1.6)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: psutil>=7 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\andre\appdata\roaming\python\python312\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\andre\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (3.0.3)
# Requirement already satisfied: wcwidth in c:\users\andre\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\andre\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# [notice] A new release of pip is available: 24.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl, FullScreenControl, MiniMap, basemaps

# Rebuild the composite map — polygon layer starts hidden (visible=False)
m = Map(center=WICHITA_FALLS, zoom=12, basemap=basemaps.Esri.WorldImagery)

poly_layer = GeoJSON(data=make_fc(polygons), name="Park Boundary", visible=False)

# Add the remaining layers
m.add(poly_layer)
m.add(GeoJSON(data=make_fc(points), name="Points"))
m.add(GeoJSON(data=make_fc(lines), name="Lines"))

# Add all four controls
m.add(LayersControl())
m.add(ScaleControl())
m.add(FullscreenControl())
m.add(MiniMap(position="bottomright"))

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl, FullScreenControl, basemaps
#       2
#       3 # Rebuild the composite map — polygon layer starts hidden (visible=False)
# ----> 4 m = Map(center=WICHITA_FALLS, zoom=12, basemap=basemaps.Esri.WorldImagery)
#       5
#       6 poly_layer = GeoJSON(data=make_fc(polygons), name="Park Boundary", visible=False)
#       7
#
# NameError: name 'WICHITA_FALLS' is not defined

# %% [markdown]
# ## Exercise B
#
# ipyleaflet layers have a `visible` attribute you can set at any time — the map updates live without re-rendering.
#
# 1. Rebuild the composite map with the polygon layer starting **hidden** (`visible=False`)
# 2. Display the map — confirm the polygon layer is absent
# 3. In a new cell, set `poly_layer.visible = True` and watch the map update in place

# %%
from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl, FullscreenControl, MiniMap, basemaps

m = Map(center=WICHITA_FALLS, zoom=12, basemap=basemaps.Esri.WorldImagery)

poly_layer = GeoJSON(data=make_fc(polygons), name="Park Boundary", visible=False)

point_layer = GeoJSON(data=make_fc(points), name="Points")
line_layer = GeoJSON(data=make_fc(lines), name="Lines")

m.add(point_layer)
m.add(line_layer)
m.add(poly_layer)

m.add(LayersControl())
m.add(ScaleControl(position="bottomright"))
m.add(FullscreenControl())
m.add(MiniMap(position="bottomright"))

m

# %% [markdown]
# ---
#
# ## Check Your Understanding
#
# Build a map centered on Wichita Falls at zoom 12 with:
# - **two named GeoJSON layers** (points and polygons from `data/wichita_falls.geojson`)
# - a `LayersControl` so both can be toggled
# - a `ScaleControl` in the bottom-right corner
#
# ```python
# # your answer here
# ```

# %%
from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl

m = Map(center=WICHITA_FALLS, zoom=12)

point_layer = GeoJSON(data=make_fc(points), name="Points")
poly_layer = GeoJSON(data=make_fc(polygons), name="Polygons")

m.add(point_layer)
m.add(poly_layer)

m.add(LayersControl())
m.add(ScaleControl(position="bottomright"))

m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Next
#
# In [03 — Attributes, Styling, and Filtering](../03-Attributes_Styling_Filtering/00-Properties.ipynb), we start reading feature properties and using them to style layers dynamically.

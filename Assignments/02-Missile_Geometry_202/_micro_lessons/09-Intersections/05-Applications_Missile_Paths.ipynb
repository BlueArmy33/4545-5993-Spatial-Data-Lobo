# %% [markdown]
# # 05 — Applications: Missile Paths
#
# Every tool built across this course so far was building toward something. This notebook puts them together:
#
# ```
# two points
#     │
#     ├─ haversine_km    →  range in kilometers
#     ├─ compute_bearing →  launch azimuth in degrees
#     └─ intersection    →  countries whose airspace is crossed
# ```
#
# Given a launch point and a target, we can now produce a complete geometric picture of the engagement.

# %% [markdown]
# ## Setup

# %%
import json
import math
from pathlib import Path
from ipyleaflet import Map, GeoJSON, LayersControl, basemaps

DATA_DIR = Path("data")

with open(DATA_DIR / "paths.geojson") as f:
    module_paths = json.load(f)

with open(DATA_DIR / "countries.geojson") as f:
    countries_fc = json.load(f)


# ── Distance & bearing (from modules 06 and 07) ──────────────────────────────

def haversine_km(lon1, lat1, lon2, lat2):
    R = 6371.0
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi  = math.radians(lat2 - lat1)
    dlam  = math.radians(lon2 - lon1)
    a = math.sin(dphi/2)**2 + math.cos(phi1)*math.cos(phi2)*math.sin(dlam/2)**2
    return R * 2 * math.asin(math.sqrt(a))

def compute_bearing(lon1, lat1, lon2, lat2):
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dlam = math.radians(lon2 - lon1)
    x = math.sin(dlam) * math.cos(phi2)
    y = math.cos(phi1)*math.sin(phi2) - math.sin(phi1)*math.cos(phi2)*math.cos(dlam)
    return (math.degrees(math.atan2(x, y)) + 360) % 360


# ── Intersection helpers (from notebooks 01–04) ───────────────────────────────

def orientation(p, q, r):
    return (q[0]-p[0])*(r[1]-q[1]) - (q[1]-p[1])*(r[0]-q[0])

def on_segment(p, q, r):
    return (min(p[0],r[0]) <= q[0] <= max(p[0],r[0]) and
            min(p[1],r[1]) <= q[1] <= max(p[1],r[1]))

def segments_intersect(p1, p2, p3, p4):
    d1=orientation(p3,p4,p1); d2=orientation(p3,p4,p2)
    d3=orientation(p1,p2,p3); d4=orientation(p1,p2,p4)
    if (d1>0 and d2<0 or d1<0 and d2>0) and (d3>0 and d4<0 or d3<0 and d4>0): return True
    if d1==0 and on_segment(p3,p1,p4): return True
    if d2==0 and on_segment(p3,p2,p4): return True
    if d3==0 and on_segment(p1,p3,p2): return True
    if d4==0 and on_segment(p1,p4,p2): return True
    return False

def polygon_edges(geometry):
    rings = geometry["coordinates"] if geometry["type"]=="Polygon" \
            else [ring for poly in geometry["coordinates"] for ring in poly]
    return [(ring[i], ring[i+1]) for ring in rings for i in range(len(ring)-1)]

def segment_bbox(p1, p2):
    return (min(p1[0],p2[0]),min(p1[1],p2[1]),max(p1[0],p2[0]),max(p1[1],p2[1]))

def geometry_bbox(geometry):
    rings = geometry["coordinates"] if geometry["type"]=="Polygon" \
            else [ring for poly in geometry["coordinates"] for ring in poly]
    coords = [pt for ring in rings for pt in ring]
    return (min(c[0] for c in coords), min(c[1] for c in coords),
            max(c[0] for c in coords), max(c[1] for c in coords))

def bboxes_overlap(b1, b2):
    return not (b1[2]<b2[0] or b2[2]<b1[0] or b1[3]<b2[1] or b2[3]<b1[1])

def path_crosses_feature(path_feature, country_feature):
    coords = path_feature["geometry"]["coordinates"]
    geom   = country_feature["geometry"]
    if geom is None: return False
    cbox  = geometry_bbox(geom)
    edges = polygon_edges(geom)
    for i in range(len(coords)-1):
        p1, p2 = coords[i], coords[i+1]
        if not bboxes_overlap(segment_bbox(p1, p2), cbox): continue
        for e1, e2 in edges:
            if segments_intersect(p1, p2, e1, e2): return True
    return False

def find_crossed_countries(path_feature, countries_fc):
    return [c for c in countries_fc["features"] if path_crosses_feature(path_feature, c)]

if isinstance(countries_fc, list):
    countries_fc = {"type": "FeatureCollection", "features": countries_fc}

print(f"Loaded {len(module_paths['features'])} paths, {len(countries_fc['features'])} countries.")
# Out:
# Loaded 4 paths, 255 countries.

# %% [markdown]
# ## From Geometry to Intelligence
#
# A single `path_report` function combines all three analyses. Given one path feature, it returns:
#
# - **Range** — great-circle distance from launch to target
# - **Bearing** — initial azimuth from launch point (0° = North, clockwise)
# - **Airspace** — sorted list of countries whose borders the path crosses

# %%
def path_report(path_feature, countries_fc):
    """
    Returns a dict with range_km, bearing_deg, and crossed_countries
    for a 2-point (or multi-point) path feature.
    """
    props = path_feature["properties"]
    coords = path_feature["geometry"]["coordinates"]
    lon1, lat1 = coords[0]
    lon2, lat2 = coords[-1]

    crossed = find_crossed_countries(path_feature, countries_fc)

    return {
        "name":             props.get("name") or props.get("Name") or f"{props.get('origin', 'Unknown')} → {props.get('destination', 'Unknown')}",
        "origin":           props.get("origin") or props.get("Origin", "Unknown"),
        "destination":      props.get("destination") or props.get("Destination", "Unknown"),
        "range_km":         round(haversine_km(lon1, lat1, lon2, lat2)),
        "bearing_deg":      round(compute_bearing(lon1, lat1, lon2, lat2), 1),
        "crossed_countries": sorted(c["properties"]["name"] for c in crossed),
    }


# Run for all four paths
def path_report(path_feature, countries_fc):
    """
    Returns a dict with range_km, bearing_deg, and crossed_countries
    for a 2-point (or multi-point) path feature.
    """
    props = path_feature["properties"]
    coords = path_feature["geometry"]["coordinates"]
    lon1, lat1 = coords[0]
    lon2, lat2 = coords[-1]

    crossed = find_crossed_countries(path_feature, countries_fc)

    return {
        "name":             props.get("name") or props.get("Name") or f"{props.get('origin', 'Unknown')} → {props.get('destination', 'Unknown')}",
        "origin":           props.get("origin") or props.get("Origin", "Unknown"),
        "destination":      props.get("destination") or props.get("Destination", "Unknown"),
        "range_km":         round(haversine_km(lon1, lat1, lon2, lat2)),
        "bearing_deg":      round(compute_bearing(lon1, lat1, lon2, lat2), 1),
        "crossed_countries": sorted(c["properties"].get("name", "Unknown") for c in crossed),
    }


# Run for all four paths
reports = [path_report(p, countries_fc) for p in module_paths["features"]]

for r in reports:
    print(f"\n{'─'*55}")
    print(f"  {r['name']}:  {r['origin']} → {r['destination']}")
    print(f"  Range:   {r['range_km']:,} km")
    print(f"  Bearing: {r['bearing_deg']}°")
    print(f"  Airspace ({len(r['crossed_countries'])} countries):")
    for country in r['crossed_countries']:
        print(f"    {country}")

for r in reports:
    print(f"\n{'─'*55}")
    print(f"  {r['name']}:  {r['origin']} → {r['destination']}")
    print(f"  Range:   {r['range_km']:,} km")
    print(f"  Bearing: {r['bearing_deg']}°")
    print(f"  Airspace ({len(r['crossed_countries'])} countries):")
    for country in r['crossed_countries']:
        print(f"    {country}")
# Out:
# ───────────────────────────────────────────────────────
#   Alpha:  Washington D.C. → Tehran
#   Range:   10,175 km
#   Bearing: 39.5°
#   Airspace (10 countries):
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#
# ───────────────────────────────────────────────────────
#   Bravo:  Pyongyang → Honolulu
#   Range:   7,394 km
#   Bearing: 80.9°
#   Airspace (16 countries):
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#
# ───────────────────────────────────────────────────────
#   Charlie:  Caracas → Madrid
#   Range:   6,992 km
#   Bearing: 49.8°
#   Airspace (4 countries):
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#
# ───────────────────────────────────────────────────────
#   Delta:  Moscow → Riyadh
#   Range:   3,532 km
#   Bearing: 164.2°
#   Airspace (6 countries):
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#
# ───────────────────────────────────────────────────────
#   Alpha:  Washington D.C. → Tehran
#   Range:   10,175 km
#   Bearing: 39.5°
#   Airspace (10 countries):
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#
# ───────────────────────────────────────────────────────
#   Bravo:  Pyongyang → Honolulu
#   Range:   7,394 km
#   Bearing: 80.9°
#   Airspace (16 countries):
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#
# ───────────────────────────────────────────────────────
#   Charlie:  Caracas → Madrid
#   Range:   6,992 km
#   Bearing: 49.8°
#   Airspace (4 countries):
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#
# ───────────────────────────────────────────────────────
#   Delta:  Moscow → Riyadh
#   Range:   3,532 km
#   Bearing: 164.2°
#   Airspace (6 countries):
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown
#     Unknown

# %% [markdown]
# ## Visualizing One Path: Full Picture
#
# A map that shows the path, the highlighted airspace, and the clean background together gives the complete picture in one view.

# %%
def path_map(path_feature, countries_fc, path_color="#e74c3c", zoom=3, center=(35, 25)):
    """
    Returns a Map showing the path and its crossed countries highlighted.
    """
    crossed  = find_crossed_countries(path_feature, countries_fc)
    hit_names = {c["properties"].get("name", "Unknown") for c in crossed}

    hit_fc  = {"type": "FeatureCollection",
               "features": [c for c in countries_fc["features"]
                             if c["properties"].get("name", "Unknown") in hit_names]}
    miss_fc = {"type": "FeatureCollection",
               "features": [c for c in countries_fc["features"]
                             if c["properties"].get("name", "Unknown") not in hit_names]}

    m = Map(center=center, zoom=zoom, basemap=basemaps.CartoDB.Positron)
    m.add(GeoJSON(data=miss_fc,
                  style={"color": "#95a5a6", "fillColor": "#95a5a6",
                         "fillOpacity": 0.1, "weight": 0.4}))
    m.add(GeoJSON(data=hit_fc,
                  style={"color": path_color, "fillColor": path_color,
                         "fillOpacity": 0.5, "weight": 1.5}))
    m.add(GeoJSON(data={"type": "FeatureCollection", "features": [path_feature]},
                  style={"color": path_color, "weight": 3, "opacity": 0.95}))
    return m


# Show the Bravo path: Pyongyang → Honolulu
bravo = next(f for f in module_paths["features"] if f["properties"]["name"] == "Bravo")
path_map(bravo, countries_fc, path_color="#2980b9", zoom=2, center=(40, -100))
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# ## Summary Table
#
# A tabular summary is often more useful for briefing than individual maps. Build it with a simple loop.

# %%
print(f"{'Name':<10} {'Origin → Destination':<38} {'Range':>8}  {'Bearing':>8}  {'Countries':>10}")
print("─" * 80)
for r in reports:
    label = f"{r['origin']} → {r['destination']}"
    print(f"{r['name']:<10} {label:<38} {r['range_km']:>7,}km  {r['bearing_deg']:>7}°  {len(r['crossed_countries']):>10}")
# Out:
# Name       Origin → Destination                      Range   Bearing   Countries
# ────────────────────────────────────────────────────────────────────────────────
# Alpha      Washington D.C. → Tehran                10,175km     39.5°          10
# Bravo      Pyongyang → Honolulu                     7,394km     80.9°          16
# Charlie    Caracas → Madrid                         6,992km     49.8°           4
# Delta      Moscow → Riyadh                          3,532km    164.2°           6

# %% [markdown]
# ## Exercise A
#
# Add a new path to the module dataset: a launch from **Beijing** (`[116.407, 39.904]`) to **Berlin** (`[13.405, 52.520]`) named `"Echo"`.
#
# 1. Build the Feature dict and append it to `module_paths["features"]`.
# 2. Call `path_report` on it and print the full result.
# 3. Display it with `path_map` using color `"#8e44ad"`.

# %%
# 1. Build the Echo Feature and append to module_paths
echo = {
    "type": "Feature",
    "properties": {
        "name": "Echo",
        "origin": "Beijing",
        "destination": "Berlin"
    },
    "geometry": {
        "type": "LineString",
        "coordinates": [
            [116.407, 39.904],  # Beijing
            [13.405, 52.520]    # Berlin
        ]
    }
}

module_paths["features"].append(echo)


# 2. Generate and print the path_report
echo_report = path_report(echo, countries_fc)

print(echo_report)


# 3. Display with path_map
path_map(
    echo,
    countries_fc,
    path_color="#8e44ad",
    zoom=3,
    center=(50, 65)
)
# Out:
# {'name': 'Echo', 'origin': 'Beijing', 'destination': 'Berlin', 'range_km': 7358, 'bearing_deg': 319.6, 'crossed_countries': ['Unknown', 'Unknown', 'Unknown', 'Unknown', 'Unknown', 'Unknown']}
# Map(center=[50, 65], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %% [markdown]
# ## Exercise B
#
# Using all paths now in `module_paths` (including Echo from Exercise A):
#
# 1. Find the path with the **greatest range**.
# 2. Find the path that crosses the **most countries**.
# 3. Find any **country that appears in more than one path's airspace** — list those countries and which paths they appear in.

# %%
# Make sure reports includes Echo before running this
reports = [path_report(p, countries_fc) for p in module_paths["features"]]


# 1. Path with greatest range
greatest_range = max(reports, key=lambda r: r["range_km"])

print("Path with greatest range:")
print(f"{greatest_range['name']}: {greatest_range['origin']} → {greatest_range['destination']}")
print(f"Range: {greatest_range['range_km']:,} km")


# 2. Path crossing the most countries
most_countries = max(reports, key=lambda r: len(r["crossed_countries"]))

print("\nPath crossing the most countries:")
print(f"{most_countries['name']}: {most_countries['origin']} → {most_countries['destination']}")
print(f"Countries crossed: {len(most_countries['crossed_countries'])}")


# 3. Countries appearing in multiple paths' airspace
country_to_paths = {}

for r in reports:
    for country in r["crossed_countries"]:
        if country not in country_to_paths:
            country_to_paths[country] = []
        country_to_paths[country].append(r["name"])

shared_countries = {
    country: paths
    for country, paths in country_to_paths.items()
    if len(paths) > 1
}

print("\nCountries appearing in more than one path's airspace:")

for country in sorted(shared_countries):
    paths = ", ".join(shared_countries[country])
    print(f"{country}: {paths}")
# Out:
# Path with greatest range:
# Alpha: Washington D.C. → Tehran
# Range: 10,175 km
#
# Path crossing the most countries:
# Bravo: Pyongyang → Honolulu
# Countries crossed: 16
#
# Countries appearing in more than one path's airspace:
# Unknown: Alpha, Alpha, Alpha, Alpha, Alpha, Alpha, Alpha, Alpha, Alpha, Alpha, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Bravo, Charlie, Charlie, Charlie, Charlie, Delta, Delta, Delta, Delta, Delta, Delta, Echo, Echo, Echo, Echo, Echo, Echo

# %% [markdown]
# ---
#
# ## Check Your Understanding
#
# **1.** Why is intersection detection important for route and path analysis — what decisions does it support that distance and bearing alone cannot?
#
# **2.** This module uses straight-line `LineString` paths. How would the intersection results change if the path curved along the actual great-circle arc, and in what direction would the error likely go?
#
# ```python
# # No code needed — answer in your own words
# ```

# %% [markdown]
# ## Check Your Understanding
#
# ### 1.
# Why is intersection detection important for route and path analysis — what decisions does it support that distance and bearing alone cannot?
#
# Distance and bearing only describe:
# - how far a path travels
# - and the direction it moves
#
# They do not describe what the path passes through.
#
# Intersection detection is important because it determines:
# - which countries or regions a route enters
# - whether a route violates restricted airspace
# - which borders are crossed
# - possible geopolitical or legal issues
# - which zones require permission, monitoring, or avoidance
#
# For example, two routes could have nearly identical distance and bearing values but pass through completely different countries.
#
# Intersection analysis supports decisions such as:
# - airspace authorization
# - military route planning
# - shipping/navigation safety
# - restricted zone avoidance
# - emergency rerouting
# - geographic risk assessment
#
# ---
#
# ### 2.
# This module uses straight-line `LineString` paths. How would the intersection results change if the path curved along the actual great-circle arc, and in what direction would the error likely go?
#
# A straight `LineString` in longitude/latitude space does not perfectly follow Earth's curvature. Real long-distance travel usually follows a great-circle route, which curves on most map projections.
#
# If the path followed the actual great-circle arc:
# - the route would shift northward or southward depending on the endpoints
# - some countries currently intersected might no longer be crossed
# - other countries might become newly intersected
#
# For long intercontinental routes, the error would usually grow larger as distance increases.
#
# In many world map projections, great-circle routes between distant cities tend to curve toward the poles, so straight-line paths often underestimate that curvature and produce slightly inaccurate intersection results.

# %% [markdown]
# ## Next
#
# Module 09 is complete. The next module introduces **spatial buffers** — expanding a point or path by a distance to model blast radius, exclusion zones, and proximity queries.

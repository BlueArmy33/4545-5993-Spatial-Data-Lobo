# %% [markdown]
# # 05 — CRS Limitations
#
# Every buffer we have built so far uses the **destination point formula** — kilometer-accurate, spherically correct. But many real-world analyses skip this and use **degree offsets** instead:
#
# ```python
# # naive — wrong
# lon + r * cos(angle),  lat + r * sin(angle)
# ```
#
# This looks like a circle on the screen, but it is an **oval** in the real world. The distortion is invisible at low latitudes and severe at high latitudes — which means it fails exactly in the places (Arctic, Northern Europe, Russia, Canada) where precision matters most.

# %% [markdown]
# ## Setup

# %%
import math
from ipyleaflet import Map, GeoJSON, LayersControl, basemaps


# Kilometer-accurate buffer (spherical Earth)
def destination_point(lon, lat, bearing_deg, distance_km):
    R = 6371.0
    d = distance_km / R
    phi1 = math.radians(lat)
    lam1 = math.radians(lon)
    theta = math.radians(bearing_deg)
    phi2 = math.asin(math.sin(phi1)*math.cos(d) + math.cos(phi1)*math.sin(d)*math.cos(theta))
    lam2 = lam1 + math.atan2(math.sin(theta)*math.sin(d)*math.cos(phi1),
                              math.cos(d) - math.sin(phi1)*math.sin(phi2))
    return [math.degrees(lam2), math.degrees(phi2)]

def km_buffer(lon, lat, radius_km, n_points=64):
    """True circular buffer in kilometers."""
    ring = [destination_point(lon, lat, 360.0*i/n_points, radius_km) for i in range(n_points)]
    ring.append(ring[0])
    return {"type": "Polygon", "coordinates": [ring]}

def degree_buffer(lon, lat, radius_deg, n_points=64):
    """Naive degree-offset buffer — oval in reality."""
    ring = []
    for i in range(n_points):
        angle = 2 * math.pi * i / n_points
        ring.append([lon + radius_deg * math.cos(angle),
                     lat + radius_deg * math.sin(angle)])
    ring.append(ring[0])
    return {"type": "Polygon", "coordinates": [ring]}

print("Both buffer functions defined.")
# Out:
# Both buffer functions defined.

# %% [markdown]
# ## Why Degrees Are Not Meters
#
# The Earth is a sphere. One degree of **latitude** is always ≈ 111 km — latitude lines are equally spaced.
#
# One degree of **longitude** depends on where you are:
#
# ```
# 1° longitude ≈ 111 × cos(latitude) km
# ```
#
# | Latitude | 1° longitude ≈ |
# |---|---|
# | 0° (equator) | 111 km |
# | 20° | 104 km |
# | 35° | 91 km |
# | 45° | 78 km |
# | 55° | 64 km |
# | 60° | 56 km |
# | 70° | 38 km |
#
# A degree-offset circle uses the same number of degrees in every direction. But each degree of longitude represents fewer kilometers as latitude increases — so the circle is stretched east-west compared to its true km size.

# %%
# Show the shrinking km/degree relationship
print(f"{'Latitude':>10}  {'1° lon (km)':>12}  {'E-W stretch factor':>20}")
print("─" * 48)
for lat in [0, 20, 35, 45, 55, 60, 70]:
    km_per_deg = 111.0 * math.cos(math.radians(lat))
    # stretch: how many km does 1° lon represent vs 1° lat (111 km)
    stretch = 111.0 / km_per_deg if km_per_deg > 0 else float('inf')
    print(f"  {lat:>7}°  {km_per_deg:>11.1f}  {stretch:>19.2f}x")
# Out:
#   Latitude   1° lon (km)    E-W stretch factor
# ────────────────────────────────────────────────
#         0°        111.0                 1.00x
#        20°        104.3                 1.06x
#        35°         90.9                 1.22x
#        45°         78.5                 1.41x
#        55°         63.7                 1.74x
#        60°         55.5                 2.00x
#        70°         38.0                 2.92x

# %% [markdown]
# ## Side-by-Side Comparison: Equator vs High Latitude
#
# To make the distortion visible, we overlay the naive degree buffer (red) and the km-accurate buffer (blue) at the same location.
#
# - At the equator: nearly identical
# - At 60°N: the degree buffer is visibly wider east-west than the km buffer
#
# We choose a `radius_deg` such that the degree buffer has roughly the same *north-south* extent as the km buffer (since 1° lat ≈ 111 km, `radius_deg ≈ radius_km / 111`).

# %%
RADIUS_KM  = 500
RADIUS_DEG = RADIUS_KM / 111.0   # match north-south extent

# --- Equator comparison ---
eq_lon, eq_lat = 20.0, 0.0

eq_km_feat  = {"type": "Feature", "properties": {"label": "km buffer"},
               "geometry": km_buffer(eq_lon, eq_lat, RADIUS_KM)}
eq_deg_feat = {"type": "Feature", "properties": {"label": "degree buffer"},
               "geometry": degree_buffer(eq_lon, eq_lat, RADIUS_DEG)}

m_eq = Map(center=(eq_lat, eq_lon), zoom=4, basemap=basemaps.CartoDB.Positron)
m_eq.add(GeoJSON(
    data={"type": "FeatureCollection", "features": [eq_deg_feat]},
    name="Degree buffer (equator)",
    style={"color": "#e74c3c", "fillColor": "#e74c3c", "fillOpacity": 0.2, "weight": 2}
))
m_eq.add(GeoJSON(
    data={"type": "FeatureCollection", "features": [eq_km_feat]},
    name="km buffer (equator)",
    style={"color": "#2980b9", "fillColor": "#2980b9", "fillOpacity": 0.2, "weight": 2}
))
m_eq.add(LayersControl())

print(f"Equator (0°): radius_deg={RADIUS_DEG:.2f}°  radius_km={RADIUS_KM} km")
print("At the equator, the two buffers are nearly identical.")
m_eq
# Out:
# Equator (0°): radius_deg=4.50°  radius_km=500 km
# At the equator, the two buffers are nearly identical.
# Map(center=[0.0, 20.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_…

# %%
# --- 60°N comparison ---
hi_lon, hi_lat = 20.0, 60.0

hi_km_feat  = {"type": "Feature", "properties": {"label": "km buffer"},
               "geometry": km_buffer(hi_lon, hi_lat, RADIUS_KM)}
hi_deg_feat = {"type": "Feature", "properties": {"label": "degree buffer"},
               "geometry": degree_buffer(hi_lon, hi_lat, RADIUS_DEG)}

m_hi = Map(center=(hi_lat, hi_lon), zoom=4, basemap=basemaps.CartoDB.Positron)
m_hi.add(GeoJSON(
    data={"type": "FeatureCollection", "features": [hi_deg_feat]},
    name="Degree buffer (60°N)",
    style={"color": "#e74c3c", "fillColor": "#e74c3c", "fillOpacity": 0.2, "weight": 2}
))
m_hi.add(GeoJSON(
    data={"type": "FeatureCollection", "features": [hi_km_feat]},
    name="km buffer (60°N)",
    style={"color": "#2980b9", "fillColor": "#2980b9", "fillOpacity": 0.2, "weight": 2}
))
m_hi.add(LayersControl())

# Compute actual E-W extent of each buffer
km_per_lon_at_60 = 111.0 * math.cos(math.radians(60))
km_ew_deg  = RADIUS_DEG * 2 * 111.0       # degree buffer E-W in km equivalent
km_ew_km   = RADIUS_KM * 2                # true km buffer E-W
print(f"At 60°N: 1° lon ≈ {km_per_lon_at_60:.1f} km")
print(f"Degree buffer E-W span ≈ {km_ew_deg:.0f} km (as measured N-S)")
print(f"km buffer E-W span = {km_ew_km} km (correct)")
print(f"Degree buffer is ~{km_ew_deg/km_ew_km:.1f}x wider than the real buffer E-W")
m_hi
# Out:
# At 60°N: 1° lon ≈ 55.5 km
# Degree buffer E-W span ≈ 1000 km (as measured N-S)
# km buffer E-W span = 1000 km (correct)
# Degree buffer is ~1.0x wider than the real buffer E-W
# Map(center=[60.0, 20.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…

# %% [markdown]
# ## Quantifying the Error
#
# For a 500 km buffer, the E-W error of the naive approach grows rapidly with latitude. We measure this as the *east-west excess* — how many km wider the degree buffer is compared to the true km buffer.

# %%
R_KM  = 500   # km
R_DEG = R_KM / 111.0

print(f"Buffer radius: {R_KM} km  ({R_DEG:.3f}°)")
print()
print(f"{'Latitude':>10}  {'km/1° lon':>10}  {'Deg-buf E-W (km)':>18}  {'True E-W (km)':>14}  {'Error':>8}")
print("─" * 68)
for lat in [0, 10, 20, 30, 45, 55, 60, 70]:
    km_per_lon  = 111.0 * math.cos(math.radians(lat))
    deg_ew_km   = R_DEG * 2 * km_per_lon   # actual km spanned by degree buffer in E-W direction
    true_ew_km  = R_KM * 2
    error_pct   = 100.0 * (true_ew_km - deg_ew_km) / true_ew_km
    print(f"  {lat:>7}°  {km_per_lon:>9.1f}  {deg_ew_km:>17.0f}  {true_ew_km:>13.0f}  {error_pct:>6.1f}%")
print()
print("Negative error means degree buffer is NARROWER than true in E-W (km/deg < 111).")
print("The degree buffer E-W is shrinking while N-S stays constant → oval, not circle.")
# Out:
# Buffer radius: 500 km  (4.505°)
#
#   Latitude   km/1° lon    Deg-buf E-W (km)   True E-W (km)     Error
# ────────────────────────────────────────────────────────────────────
#         0°      111.0               1000           1000     0.0%
#        10°      109.3                985           1000     1.5%
#        20°      104.3                940           1000     6.0%
#        30°       96.1                866           1000    13.4%
#        45°       78.5                707           1000    29.3%
#        55°       63.7                574           1000    42.6%
#        60°       55.5                500           1000    50.0%
#        70°       38.0                342           1000    65.8%
#
# Negative error means degree buffer is NARROWER than true in E-W (km/deg < 111).
# The degree buffer E-W is shrinking while N-S stays constant → oval, not circle.

# %% [markdown]
# ## When Does It Matter?
#
# The distortion is proportional to latitude:
#
# | Use case | Typical latitude | Degree buffer error |
# |---|---|---|
# | Middle East targets (Tehran, Riyadh) | 25–36°N | ~10–20% |
# | European targets (Madrid, Berlin) | 40–52°N | ~25–35% |
# | High-latitude (Moscow, Oslo) | 55–60°N | ~40–50% |
# | Arctic scenarios | 70–80°N | >60% |
#
# A 500 km lethal zone modeled with a degree offset could be 200 km too narrow east-west at 60°N — which would exclude cities that are genuinely within range. For analysis that affects real decisions, this is an unacceptable error.

# %% [markdown]
# ## Exercise A
#
# Compare degree-offset vs km-accurate 300 km buffers at **three latitudes**: 10°N, 35°N, and 65°N (all at the same longitude, e.g. 30°E).
#
# 1. Create a map showing all six buffers (two per latitude, different colors per method).
# 2. Print the E-W span in km for the degree buffer and the km buffer at each latitude.
# 3. At which latitude does the distortion first exceed 25%?

# %%
from ipyleaflet import Map, GeoJSON, LayersControl, basemaps
import math

RADIUS_KM = 300
LON = 30.0
LATITUDES = [10, 35, 65]

radius_deg = RADIUS_KM / 111.0

# Create map
m = Map(center=(35, LON), zoom=3, basemap=basemaps.CartoDB.Positron)

print(f"{'Latitude':>10} {'Degree E-W span':>18} {'KM buffer E-W span':>20} {'Distortion':>14}")
print("-" * 70)

first_over_25 = None

for lat in LATITUDES:
    # Create degree-offset buffer
    deg_feat = {
        "type": "Feature",
        "properties": {"label": f"Degree buffer {lat}N"},
        "geometry": degree_buffer(LON, lat, radius_deg)
    }

    # Create km-accurate buffer
    km_feat = {
        "type": "Feature",
        "properties": {"label": f"KM buffer {lat}N"},
        "geometry": km_buffer(LON, lat, RADIUS_KM)
    }

    # Add degree buffer layer: red
    m.add(GeoJSON(
        data={"type": "FeatureCollection", "features": [deg_feat]},
        name=f"Degree buffer {lat}°N",
        style={
            "color": "#e74c3c",
            "fillColor": "#e74c3c",
            "fillOpacity": 0.18,
            "weight": 2
        }
    ))

    # Add km buffer layer: blue
    m.add(GeoJSON(
        data={"type": "FeatureCollection", "features": [km_feat]},
        name=f"KM buffer {lat}°N",
        style={
            "color": "#2980b9",
            "fillColor": "#2980b9",
            "fillOpacity": 0.18,
            "weight": 2
        }
    ))

    # E-W span comparison
    km_per_lon = 111.0 * math.cos(math.radians(lat))

    degree_ew_span = radius_deg * 2 * km_per_lon
    km_ew_span = RADIUS_KM * 2

    distortion_pct = 100.0 * (km_ew_span - degree_ew_span) / km_ew_span

    print(
        f"{lat:>8}°N "
        f"{degree_ew_span:>15.0f} km "
        f"{km_ew_span:>17.0f} km "
        f"{distortion_pct:>13.1f}%"
    )

    if distortion_pct > 25 and first_over_25 is None:
        first_over_25 = lat

m.add(LayersControl())

print()
if first_over_25 is not None:
    print(f"The distortion first exceeds 25% at {first_over_25}°N.")
else:
    print("The distortion does not exceed 25% at the tested latitudes.")

m
# Out:
#   Latitude    Degree E-W span   KM buffer E-W span     Distortion
# ----------------------------------------------------------------------
#       10°N             591 km               600 km           1.5%
#       35°N             491 km               600 km          18.1%
#       65°N             254 km               600 km          57.7%
#
# The distortion first exceeds 25% at 65°N.
# Map(center=[35, 30.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# ## Exercise B
#
# **Moscow** is at approximately `[37.617, 55.755]`.
#
# 1. Create a 600 km degree-offset buffer around Moscow.
# 2. Create a 600 km km-accurate buffer around Moscow.
# 3. Display both on the same map and describe the shape difference.
# 4. Calculate: if you used the degree buffer to decide whether a city is within 600 km, could you incorrectly *exclude* a city that is actually within range? Which direction would the error occur?

# %%
from ipyleaflet import Map, GeoJSON, LayersControl, basemaps
import math

moscow = [37.617, 55.755]

RADIUS_KM = 600
radius_deg = RADIUS_KM / 111.0

lon, lat = moscow

# 1. Degree-offset buffer
moscow_degree_feat = {
    "type": "Feature",
    "properties": {"name": "Moscow degree-offset 600 km"},
    "geometry": degree_buffer(lon, lat, radius_deg)
}

# 2. Kilometer-accurate buffer
moscow_km_feat = {
    "type": "Feature",
    "properties": {"name": "Moscow km-accurate 600 km"},
    "geometry": km_buffer(lon, lat, RADIUS_KM)
}

# Moscow point
moscow_point = {
    "type": "Feature",
    "properties": {"name": "Moscow"},
    "geometry": {
        "type": "Point",
        "coordinates": moscow
    }
}

# 3. Display both on same map
m = Map(center=(lat, lon), zoom=4, basemap=basemaps.CartoDB.Positron)

m.add(GeoJSON(
    data={"type": "FeatureCollection", "features": [moscow_degree_feat]},
    name="Degree-offset buffer",
    style={
        "color": "#e74c3c",
        "fillColor": "#e74c3c",
        "fillOpacity": 0.20,
        "weight": 2
    }
))

m.add(GeoJSON(
    data={"type": "FeatureCollection", "features": [moscow_km_feat]},
    name="KM-accurate buffer",
    style={
        "color": "#2980b9",
        "fillColor": "#2980b9",
        "fillOpacity": 0.20,
        "weight": 2
    }
))

m.add(GeoJSON(
    data={"type": "FeatureCollection", "features": [moscow_point]},
    name="Moscow point",
    style={
        "color": "#2c3e50",
        "fillColor": "#2c3e50",
        "fillOpacity": 0.9,
        "weight": 2
    }
))

m.add(LayersControl())

# 4. Calculate east-west distortion
km_per_lon = 111.0 * math.cos(math.radians(lat))

degree_ew_span = radius_deg * 2 * km_per_lon
true_ew_span = RADIUS_KM * 2

error_pct = 100.0 * (true_ew_span - degree_ew_span) / true_ew_span

print(f"Moscow latitude: {lat}°N")
print(f"1° longitude at Moscow ≈ {km_per_lon:.1f} km")
print(f"Degree buffer E-W span ≈ {degree_ew_span:,.0f} km")
print(f"KM-accurate buffer E-W span = {true_ew_span:,.0f} km")
print(f"E-W underestimation: {error_pct:.1f}%")

print()
print("Shape difference:")
print("The degree-offset buffer is too narrow east-west at Moscow's latitude, while the km-accurate buffer keeps the correct 600 km distance in all directions.")

print()
print("Directional error:")
print("Yes. A degree buffer could incorrectly exclude a city that is actually within 600 km east or west of Moscow.")
print("The error occurs mainly in the east-west direction because longitude degrees shrink at higher latitudes.")

m
# Out:
# Moscow latitude: 55.755°N
# 1° longitude at Moscow ≈ 62.5 km
# Degree buffer E-W span ≈ 675 km
# KM-accurate buffer E-W span = 1,200 km
# E-W underestimation: 43.7%
#
# Shape difference:
# The degree-offset buffer is too narrow east-west at Moscow's latitude, while the km-accurate buffer keeps the correct 600 km distance in all directions.
#
# Directional error:
# Yes. A degree buffer could incorrectly exclude a city that is actually within 600 km east or west of Moscow.
# The error occurs mainly in the east-west direction because longitude degrees shrink at higher latitudes.
# Map(center=[55.755, 37.617], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom…

# %% [markdown]
# ---
#
# ## Check Your Understanding
#
# **1.** Why does the degree-offset buffer produce an oval rather than a circle, and in which direction is it distorted?
#
# **2.** At the equator, a degree buffer is nearly correct. At 60°N it is badly wrong. What changes between those two latitudes that causes this?
#
# ```python
# # No code needed — answer in your own words
# ```

# %% [markdown]
# ## Check Your Understanding
#
# ### 1.
# Why does the degree-offset buffer produce an oval rather than a circle, and in which direction is it distorted?
#
# A degree-offset buffer assumes that one degree of longitude and one degree of latitude represent the same physical distance everywhere on Earth. That assumption is false.
#
# Latitude degrees stay close to 111 km everywhere, but longitude degrees shrink as latitude increases.
#
# Because of this:
# - the north-south size stays roughly correct
# - the east-west size becomes too small at higher latitudes
#
# So the degree buffer becomes an oval that is compressed in the east-west direction instead of a true circle.
#
# ---
#
# ### 2.
# At the equator, a degree buffer is nearly correct. At 60°N it is badly wrong. What changes between those two latitudes that causes this?
#
# The key change is the physical distance represented by one degree of longitude.
#
# At the equator:
# - longitude lines are far apart
# - 1° longitude is about 111 km
# - longitude and latitude degrees are nearly equal in size
#
# At 60°N:
# - longitude lines are much closer together
# - 1° longitude is only about 55 km
# - using the same degree offset east-west covers far less real distance
#
# This shrinking east-west scale causes the degree buffer distortion to become much larger at high latitudes.

# %% [markdown]
# ## Next
#
# In [06 — Applications: Impact Zones](./06-Applications_Impact_Zones.ipynb), we apply everything from this module to a complete scenario: blast radii around targets, trajectory corridors, and identifying which locations fall within a given impact zone.
